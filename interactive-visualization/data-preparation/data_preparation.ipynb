# %%
import requests

import pandas as pd
import pandas_profiling

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# %%
google_key = 'AIzaSyBja5iAzSsWaxQQnrIzABkJDH8e43oCyK0'
country = 'Colombia'

# %% [markdown]
# # Data Loading and Preparation - Capacity Dataset

# %%
ips_df = pd.read_csv( '../data/IPSs-colombia.csv', dtype = { 'nit IPS ' : 'str' } )

# %%
#del ips_df[ 'nit IPS ' ]
del ips_df[ 'num digito_verificion' ]

# %%
ips_df.rename( columns = { 'nit IPS ' : 'NIT', 
                          'nom sede IPS' : 'Nombre', 
                          'naturaleza' : 'Naturaleza', 
                          'num nivel atencion' : 'Nivel de Atención',
                         'nom grupo capacidad ' : 'Grupo',
                         'nom descripcion capacidad ' : 'Descripción',
                         'num cantidad capacidad instalada' : 'Capacidad Instalada' }, inplace = True )

# %%
ips_df = ips_df.loc[ ips_df[ 'Grupo' ].notnull() ]

# %%
ips_df.drop_duplicates( inplace = True )

# %%
ips_df.loc[ ips_df[ 'Grupo' ] == 'CAMAS', 'Grupo' ] = 'Camas'
ips_df.loc[ ips_df[ 'Grupo' ] == 'SALAS', 'Grupo' ] = 'Salas'

# %%
ips_df.dtypes
# Out:
# Nombre                  object
# NIT                     object
# Naturaleza              object
# Nivel de Atención      float64
# Grupo                   object
# Descripción             object
# Capacidad Instalada    float64
# dtype: object

# %%
ips_df.shape
# Out:
# (10330, 7)

# %%
#pandas_profiling.ProfileReport( ips_df )

# %%
ips_df[ 'Descripción Capacidad' ] = ips_df[ 'Grupo' ] + ' ' + ips_df[ 'Descripción' ]

# %%
del ips_df[ 'Grupo' ]
del ips_df[ 'Descripción' ]

# %%
ips_df.head()
# Out:
#                Nombre        NIT Naturaleza  Nivel de Atención  \
# 0        CLINICA VIVE  900450008    Privada                NaN
# 1  CAMPONUEVO CISNE 2  830100595    Privada                NaN
# 2               COVEN  900280825    Privada                NaN
# 3       GASTROCAL SAS  900690781    Privada                NaN
# 4          DACARE IPS  900883992    Privada                NaN
#
#    Capacidad Instalada Descripción Capacidad
# 0                 44.0     Camas Psiquiatría
# 1                 15.0     Camas Psiquiatría
# 2                 12.0         Camas Adultos
# 3                  2.0  Salas Procedimientos
# 4                  2.0         Camas Adultos

# %%
ips_df[ 'Nombre' ].nunique()
# Out:
# 3723

# %%
ips_df[ 'Naturaleza' ].value_counts( dropna = False )
# Out:
# Privada    5674
# Pública    4592
# Mixta        64
# Name: Naturaleza, dtype: int64

# %%
ips_df[ 'Nivel de Atención' ].value_counts( dropna = False )
# Out:
# NaN     5739
#  1.0    3386
#  2.0     782
#  3.0     423
# Name: Nivel de Atención, dtype: int64

# %%
ips_df[ 'Capacidad Instalada' ].value_counts( dropna = False ).head()
# Out:
# 1.0    3635
# 2.0    1544
# 3.0     769
# 4.0     761
# 6.0     470
# Name: Capacidad Instalada, dtype: int64

# %%
ips_df[ 'Descripción Capacidad' ].value_counts( dropna = False )
# Out:
# Salas Procedimientos                                 1866
# Camas Adultos                                        1544
# Camas Obstetricia                                    1228
# Camas Pediátrica                                     1226
# Salas Partos                                         1176
# Salas Quirófano                                      1138
# Camas Cuidado Intensivo Adulto                        391
# Camas Cuidado Intermedio Adulto                       379
# Camas Cuidado Intermedio Neonatal                     243
# Camas Cuidado Intensivo Neonatal                      237
# Camas Cuidado básico neonatal                         201
# Camas Psiquiatría                                     168
# Camas Cuidado Intensivo Pediátrico                    133
# Camas Cuidado Intermedio Pediátrico                   126
# Camas Farmacodependencia                               98
# Camas Institución Paciente Crónico                     58
# Camas Cuidado Agudo Mental                             46
# Camas Salud Mental                                     20
# Camas Transplante de progenitores hematopoyeticos      14
# Camas Unidad de Quemados Adulto                        14
# Camas Unidad de Quemados Pediátrico                    13
# Camas Cuidado Intermedio Mental                        11
# Name: Descripción Capacidad, dtype: int64

# %% [markdown]
# # Splitting by Nature

# %%
ips_publicas_df = ips_df.loc[ ips_df[ 'Naturaleza' ] == 'Pública' ]

# %%
ips_publicas_df = ips_publicas_df.loc[ ips_publicas_df[ 'Nivel de Atención' ].notnull() ]

# %%
ips_publicas_df.shape
# Out:
# (4591, 6)

# %%
ips_no_publicas_df = ips_df.loc[ ips_df[ 'Naturaleza' ] != 'Pública' ]

# %%
ips_no_publicas_df.shape
# Out:
# (5738, 6)

# %% [markdown]
# # Unstacking

# %% [markdown]
# ### Públicas

# %%
ips_publicas_df.sort_values( by = [ 'NIT', 'Nombre', 'Capacidad Instalada' ], inplace = True )
ips_publicas_df.drop_duplicates( subset = [ 'NIT', 'Nombre', 'Naturaleza', 'Nivel de Atención', 'Descripción Capacidad' ], keep = 'last', inplace = True )

# %%
ips_publicas_unstacked_df = ips_publicas_df.set_index( [ 'NIT', 'Nombre', 'Naturaleza', 'Nivel de Atención', 'Descripción Capacidad' ], inplace = False ).unstack( level = -1 )

# %%
ips_publicas_unstacked_df.columns = ips_publicas_unstacked_df.columns.droplevel()

# %%
ips_publicas_unstacked_df = ips_publicas_unstacked_df.reset_index()

# %%
ips_publicas_unstacked_df.shape
# Out:
# (1342, 26)

# %%
ips_publicas_unstacked_df.head()
# Out:
# Descripción Capacidad        NIT  \
# 0                      800000118
# 1                      800006850
# 2                      800006850
# 3                      800006850
# 4                      800006850
#
# Descripción Capacidad                                             Nombre  \
# 0                      EMPRESA SOCIAL DEL ESTADO HOSPITAL UNIVERSITAR...
# 1                                             CENTRO DE CONSULTA EXTERNA
# 2                            CENTRO DE SALUD DE GRANADA - (253120038003)
# 3                             CENTRO DE SALUD DE SIBATE - (257400038002)
# 4                      E.S.E. HOSPITAL MARIO GAITAN YANGUAS DE SOACHA...
#
# Descripción Capacidad Naturaleza  Nivel de Atención  Camas Adultos  \
# 0                        Pública                3.0          212.0
# 1                        Pública                1.0            NaN
# 2                        Pública                1.0            NaN
# 3                        Pública                1.0            NaN
# 4                        Pública                1.0           38.0
#
# Descripción Capacidad  Camas Cuidado Agudo Mental  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
# Descripción Capacidad  Camas Cuidado Intensivo Adulto  \
# 0                                                14.0
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
# Descripción Capacidad  Camas Cuidado Intensivo Neonatal  \
# 0                                                   3.0
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
# Descripción Capacidad  Camas Cuidado Intensivo Pediátrico  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# Descripción Capacidad  Camas Cuidado Intermedio Adulto       ...         \
# 0                                                  4.0       ...
# 1                                                  NaN       ...
# 2                                                  NaN       ...
# 3                                                  NaN       ...
# 4                                                  NaN       ...
#
# Descripción Capacidad  Camas Obstetricia  Camas Pediátrica  Camas Psiquiatría  \
# 0                                   20.0              30.0                7.0
# 1                                    NaN               NaN                NaN
# 2                                    NaN               NaN                NaN
# 3                                    NaN               NaN                NaN
# 4                                   18.0              25.0                NaN
#
# Descripción Capacidad  Camas Salud Mental  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# Descripción Capacidad  Camas Transplante de progenitores hematopoyeticos  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
#
# Descripción Capacidad  Camas Unidad de Quemados Adulto  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
# Descripción Capacidad  Camas Unidad de Quemados Pediátrico  Salas Partos  \
# 0                                                      NaN           NaN
# 1                                                      NaN           NaN
# 2                                                      NaN           NaN
# 3                                                      NaN           NaN
# 4                                                      NaN           2.0
#
# Descripción Capacidad  Salas Procedimientos  Salas Quirófano
# 0                                       NaN              6.0
# 1                                       1.0              NaN
# 2                                       1.0              NaN
# 3                                       1.0              NaN
# 4                                       1.0              3.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ### No Públicas

# %%
del ips_no_publicas_df[ 'Nivel de Atención' ]

# %%
ips_no_publicas_df.sort_values( by = [ 'NIT', 'Nombre', 'Capacidad Instalada' ], inplace = True )
ips_no_publicas_df.drop_duplicates( subset = [ 'NIT', 'Nombre', 'Naturaleza', 'Descripción Capacidad' ], keep = 'last', inplace = True )
# Out:
# C:\Users\fc.pena\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\fc.pena\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
ips_no_publicas_unstacked_df = ips_no_publicas_df.set_index( [ 'NIT', 'Nombre', 'Naturaleza', 'Descripción Capacidad' ], inplace = False ).unstack( level = -1 )

# %%
ips_no_publicas_unstacked_df.columns = ips_no_publicas_unstacked_df.columns.droplevel()

# %%
ips_no_publicas_unstacked_df = ips_no_publicas_unstacked_df.reset_index()

# %%
ips_no_publicas_unstacked_df.shape
# Out:
# (2421, 25)

# %%
ips_no_publicas_unstacked_df.head()
# Out:
# Descripción Capacidad        NIT                             Nombre  \
# 0                      800003765   VIRREY SOLIS I.P.S S.A SAN DIEGO
# 1                      800003765   VIRREY SOLIS I.P.S S.A. AMERICAS
# 2                      800003765  VIRREY SOLIS I.P.S S.A. OCCIDENTE
# 3                      800003765      VIRREY SOLIS I.P.S S.A. OLAYA
# 4                      800003765   VIRREY SOLIS IPS S. A MANZANARES
#
# Descripción Capacidad Naturaleza  Camas Adultos  Camas Cuidado Agudo Mental  \
# 0                        Privada            NaN                         NaN
# 1                        Privada            NaN                         NaN
# 2                        Privada            NaN                         NaN
# 3                        Privada            NaN                         NaN
# 4                        Privada            NaN                         NaN
#
# Descripción Capacidad  Camas Cuidado Intensivo Adulto  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
#
# Descripción Capacidad  Camas Cuidado Intensivo Neonatal  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
#
# Descripción Capacidad  Camas Cuidado Intensivo Pediátrico  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
#
# Descripción Capacidad  Camas Cuidado Intermedio Adulto  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
# Descripción Capacidad  Camas Cuidado Intermedio Mental       ...         \
# 0                                                  NaN       ...
# 1                                                  NaN       ...
# 2                                                  NaN       ...
# 3                                                  NaN       ...
# 4                                                  NaN       ...
#
# Descripción Capacidad  Camas Obstetricia  Camas Pediátrica  Camas Psiquiatría  \
# 0                                    NaN               NaN                NaN
# 1                                    NaN               NaN                NaN
# 2                                    NaN               NaN                NaN
# 3                                    NaN               NaN                NaN
# 4                                    NaN               NaN                NaN
#
# Descripción Capacidad  Camas Salud Mental  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# Descripción Capacidad  Camas Transplante de progenitores hematopoyeticos  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2                                                                    NaN
# 3                                                                    NaN
# 4                                                                    NaN
#
# Descripción Capacidad  Camas Unidad de Quemados Adulto  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
# Descripción Capacidad  Camas Unidad de Quemados Pediátrico  Salas Partos  \
# 0                                                      NaN           NaN
# 1                                                      NaN           NaN
# 2                                                      NaN           NaN
# 3                                                      NaN           NaN
# 4                                                      NaN           NaN
#
# Descripción Capacidad  Salas Procedimientos  Salas Quirófano
# 0                                       1.0              NaN
# 1                                       1.0              NaN
# 2                                       1.0              NaN
# 3                                       1.0              NaN
# 4                                       1.0              NaN
#
# [5 rows x 25 columns]

# %%
set( ips_publicas_unstacked_df.columns.tolist() ).symmetric_difference( set( ips_no_publicas_unstacked_df.columns.tolist() ) )
# Out:
# {'Nivel de Atención'}

# %% [markdown]
# # Training classifier

# %%
ips_publicas_unstacked_df = ips_publicas_unstacked_df.fillna( 0 )
ips_no_publicas_unstacked_df = ips_no_publicas_unstacked_df.fillna( 0 )

# %%
features = ips_publicas_unstacked_df.columns.tolist()
features.remove( 'NIT' )
features.remove( 'Nombre' )
features.remove( 'Naturaleza' )
features.remove( 'Nivel de Atención' )
len( features )
# Out:
# 22

# %%
model = RandomForestClassifier( n_estimators = 20, random_state = 1, n_jobs = -1 )

# %%
model.fit( ips_publicas_unstacked_df[ features ], ips_publicas_unstacked_df[ 'Nivel de Atención' ] )
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=-1,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
preds = model.predict( ips_publicas_unstacked_df[ features ] )

# %%
confusion_matrix( ips_publicas_unstacked_df[ 'Nivel de Atención' ], preds )
# Out:
# array([[1077,    2,    0],
#        [  50,  133,    0],
#        [  22,    0,   58]], dtype=int64)

# %%
# Generating new predictions
ips_no_publicas_unstacked_df[ 'Nivel de Atención' ] = model.predict( ips_no_publicas_unstacked_df[ features ] )

# %%
ips_no_publicas_unstacked_df[ 'Nivel de Atención' ].value_counts( dropna = False )
# Out:
# 1.0    1642
# 3.0     477
# 2.0     302
# Name: Nivel de Atención, dtype: int64

# %% [markdown]
# # Concatenating dataframes

# %%
ips_unstacked_df = pd.concat( [ ips_publicas_unstacked_df, ips_no_publicas_unstacked_df ] )
# Out:
# C:\Users\fc.pena\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
ips_unstacked_df[ 'Nivel de Atención' ] = ips_unstacked_df[ 'Nivel de Atención' ].astype( int )

# %%
ips_unstacked_df.shape
# Out:
# (3763, 26)

# %%
ips_unstacked_df.tail()
# Out:
#       Camas Adultos  Camas Cuidado Agudo Mental  \
# 2416            0.0                         0.0
# 2417           15.0                         0.0
# 2418            0.0                         0.0
# 2419            0.0                         0.0
# 2420            0.0                         0.0
#
#       Camas Cuidado Intensivo Adulto  Camas Cuidado Intensivo Neonatal  \
# 2416                             0.0                               0.0
# 2417                             0.0                               0.0
# 2418                             0.0                               0.0
# 2419                             0.0                               0.0
# 2420                             0.0                               0.0
#
#       Camas Cuidado Intensivo Pediátrico  Camas Cuidado Intermedio Adulto  \
# 2416                                 0.0                              0.0
# 2417                                 0.0                              0.0
# 2418                                 0.0                              0.0
# 2419                                 0.0                              0.0
# 2420                                 0.0                              0.0
#
#       Camas Cuidado Intermedio Mental  Camas Cuidado Intermedio Neonatal  \
# 2416                              0.0                                0.0
# 2417                              0.0                                0.0
# 2418                              0.0                                0.0
# 2419                              0.0                                0.0
# 2420                              0.0                                0.0
#
#       Camas Cuidado Intermedio Pediátrico  Camas Cuidado básico neonatal  \
# 2416                                  0.0                            0.0
# 2417                                  0.0                            0.0
# 2418                                  0.0                            0.0
# 2419                                  0.0                            0.0
# 2420                                  0.0                            0.0
#
#            ...        Camas Transplante de progenitores hematopoyeticos  \
# 2416       ...                                                      0.0
# 2417       ...                                                      0.0
# 2418       ...                                                      0.0
# 2419       ...                                                      0.0
# 2420       ...                                                      0.0
#
#       Camas Unidad de Quemados Adulto  Camas Unidad de Quemados Pediátrico  \
# 2416                              0.0                                  0.0
# 2417                              0.0                                  0.0
# 2418                              0.0                                  0.0
# 2419                              0.0                                  0.0
# 2420                              0.0                                  0.0
#
#             NIT  Naturaleza  Nivel de Atención  \
# 2416  901090890     Privada                  1
# 2417  901090960     Privada                  3
# 2418  901093053     Privada                  1
# 2419  901107556     Privada                  1
# 2420  901109443     Privada                  1
#
#                                       Nombre  Salas Partos  \
# 2416  IPS CENTRO DE MEDICINA INTEGRATIVA SAS           0.0
# 2417          centro hospitalario de cordoba           0.0
# 2418                    IPS ENDOFERTIL S.A.S           0.0
# 2419                 NATURQUALITY PLUS TUNJA           0.0
# 2420                CENTRO MEDICO MI DOC SAS           0.0
#
#       Salas Procedimientos Salas Quirófano
# 2416                   1.0             0.0
# 2417                   0.0             2.0
# 2418                   1.0             0.0
# 2419                   2.0             0.0
# 2420                   1.0             0.0
#
# [5 rows x 26 columns]

# %%
ips_unstacked_df.to_csv( '../data/IPSs-colombia-classified.csv', index = False, sep = ';', decimal = ',' )

# %%
ips_unstacked_df.to_csv( '../data/IPSs-colombia-classified-comma.csv', index = False, sep = ',' )

# %%
ips_unstacked_df[ 'Naturaleza' ].value_counts( dropna = False )
# Out:
# Privada    2404
# Pública    1342
# Mixta        17
# Name: Naturaleza, dtype: int64
